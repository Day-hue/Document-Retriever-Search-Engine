# %% [markdown]
# <a href="https://colab.research.google.com/github/Day-hue/Document-Retriever-Search-Engine/blob/main/experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project: Build a Document Retreiver Search Engine on Wikipedia Data.

# %% [markdown]
# ## Instal OpenAI and LangChain Dependencies

# %%
# !pip install langchain==0.2.0
# !pip install langchain.openai==0.1.7
# !pip install langchain.community==0.2.0
# !pip install sentence.transformers==2.7.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.7/973.7 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.1/397.1 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
#     Uninstalling tenacity-9.1.2:
#       Successfully uninstalled tenacity-9.1.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.39
#     Uninstalling langsmith-0.3.39:
#       Successfully uninstalled langsmith-0.3.39
# ...

# %% [markdown]
# ## Instal Chroma Vector DB and LangChain Wrapper

# %%
# !pip install langchain-chroma
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.7/437.7 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 66.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Enter OpenAI API Key

# %%
from getpass import getpass

OPENAI_KEY=getpass('Enter OpenAI API Key: ')
# Out:
# Enter OpenAI API Key: ··········

# %% [markdown]
# ## Setup Environment variables

# %%
import os
os.environ['OPENAI_API_KEY']=OPENAI_KEY

# %% [markdown]
# ## OPENAI embedding Models
# LangChain enables us to access Open AI embedding models which include the models models: a smaller and highly efficient text-embedding-3-small model, and a larger and more powerful text-embedding-3-large model.

# %%
pip install --upgrade langchain langchain-openai pydantic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.2.4
#     Uninstalling langchain-text-splitters-0.2.4:
#       Successfully uninstalled langchain-text-splitters-0.2.4
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 0.1.7
#     Uninstalling langchain-openai-0.1.7:
#       Successfully uninstalled langchain-openai-0.1.7
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.2.0
#     Uninstalling langchain-0.2.0:
#       Successfully uninstalled langchain-0.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from langchain_openai import OpenAIEmbeddings

openai_embed_model = OpenAIEmbeddings(model='text-embedding-3-small')

# %% [markdown]
# ## Vector Databases

# %% [markdown]
# ## get wikipedia data

# %%
#manually upload it on colab
# !gdown 1oWBnoxBZ1Mpeond8XDUSO6J9oAjcRDyW
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1oWBnoxBZ1Mpeond8XDUSO6J9oAjcRDyW
# From (redirected): https://drive.google.com/uc?id=1oWBnoxBZ1Mpeond8XDUSO6J9oAjcRDyW&confirm=t&uuid=8b4961a7-2179-4db4-8880-320670d038e7
# To: /content/simplewiki-2020-11-01.jsonl.gz
# 100% 50.2M/50.2M [00:00<00:00, 51.1MB/s]
